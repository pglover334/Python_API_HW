# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

from api_keys import api_key

from citipy import citipy

output_data_file = "output_data/cities.csv"

lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
lat_lngs = []
cities = []

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 615

# %%
api_key = "2853f2be790044b9ea0c667a889aff94"
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

count = 0

for city in cities:  
    try:
        count += 1
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        city_name_record = response["name"]
        print(f"Processing Record {count} | {city_name_record}")
        print(f"{url}&q={city}")
    except:
        print("City not found. Skipping...")
# Out:
# Processing Record 1 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2853f2be790044b9ea0c667a889aff94&q=punta arenas
# Processing Record 2 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2853f2be790044b9ea0c667a889aff94&q=kapaa
# Processing Record 3 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2853f2be790044b9ea0c667a889aff94&q=yellowknife
# Processing Record 4 | Ust-Ishim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2853f2be790044b9ea0c667a889aff94&q=ust-ishim
# Processing Record 5 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2853f2be790044b9ea0c667a889aff94&q=port alfred
# Processing Record 6 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2853f2be790044b9ea0c667a889aff94&q=te anau
# Processing Record 7 | Zhanakorgan
# ...

# %%
weather = {"City": city_name, "Cloudiness": cloudiness, "Country": country, "Date": date, "Humidity": humidity, "Latitude": lat, "Longitude": lng, "Max Temperature": max_temp, "Wind Speed": wind_speed}
df = pd.DataFrame(weather)
df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity  Latitude  \
# 0  Punta Arenas           0      CL  1564248051        61    -53.16
# 1         Kapaa          40      US  1564248051        74     22.08
# 2   Yellowknife          75      CA  1564248051        47     62.45
# 3     Ust-Ishim         100      RU  1564248051        93     57.69
# 4   Port Alfred           0      ZA  1564248051        70    -33.59
#
#    Longitude  Max Temperature  Wind Speed
# 0     -70.91            48.20       23.04
# 1    -159.32            78.80       16.11
# 2    -114.38            55.40        8.05
# 3      71.17            60.53        1.86
# 4      26.89            62.01        3.00

# %%
df.count()
# Out:
# City               554
# Cloudiness         554
# Country            554
# Date               554
# Humidity           554
# Latitude           554
# Longitude          554
# Max Temperature    554
# Wind Speed         554
# dtype: int64

# %%
plt.scatter(df["Latitude"], df["Max Temperature"], marker="o", s=12)
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("C:\\Users\\User\\Lat_vs_MaxTemp.png")
plt.show()

# %%
plt.scatter(df["Latitude"], df["Humidity"], marker="o", s=12)
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("C:\\Users\\User\\Lat_vs_Humidity.png")
plt.show()

# %%
plt.scatter(df["Latitude"], df["Cloudiness"], marker="o", s=12)
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("C:\\Users\\User\\Lat_vs_Cloudiness.png")
plt.show()

# %%
plt.scatter(df["Latitude"], df["Wind Speed"], marker="o", s=12)
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("C:\\Users\\User\\Lat_vs_WindSpeed.png")
plt.show()
